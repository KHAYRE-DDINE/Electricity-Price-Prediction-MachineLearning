# %% [markdown]
# # Electricity Price Prediction
# ## 1. Import Libraries

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from datetime import datetime
# %matplotlib inline

# %% [markdown]
# ## 2. Load and Explore Data

# %%
# Load data
train_data = pd.read_csv("2018_CI_Assignment_Training_Data.csv")
test_data = pd.read_csv("2018_CI_Assignment_Testing_Data.csv")

# Display basic statistics
print("Training Data Info:")
print(train_data.info())
print("\nTraining Data Description:")
print(train_data.describe())

# Check for outliers in the target variable
plt.figure(figsize=(10, 6))
sns.boxplot(x=train_data['P(t+1)'])
plt.title('Boxplot of P(t+1) - Target Variable')
plt.show()
# Out:
# Training Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956 entries, 0 to 955
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   T(t-2)  956 non-null    float64
#  1   T(t-1)  956 non-null    float64
#  2   T(t)    956 non-null    float64
#  3   D(t-2)  956 non-null    float64
#  4   D(t-1)  956 non-null    float64
#  5   D(t)    956 non-null    float64
#  6   P(t+1)  956 non-null    float64
# dtypes: float64(7)
# memory usage: 52.4 KB
# None
#
# Training Data Description:
#            T(t-2)      T(t-1)        T(t)       D(t-2)       D(t-1)  \
# count  956.000000  956.000000  956.000000   956.000000   956.000000
# mean    26.603033   26.602615   26.601151  5394.542678  5394.842573
# std      2.564073    2.564629    2.566345   784.876009   784.638352
# min     20.900000   20.900000   20.900000  3807.600000  3807.600000
# 25%     24.600000   24.600000   24.600000  4662.125000  4664.475000
# ...

# %% [markdown]
# ## 3. Data Preprocessing

# %%
# Handle outliers in training data
price_mean = train_data['P(t+1)'].mean()
price_std = train_data['P(t+1)'].std()
threshold = price_mean + 3 * price_std
print(f"Price threshold for outliers: {threshold:.2f}")

# Remove outliers
train_clean = train_data[train_data['P(t+1)'] < threshold].copy()
print(f"Removed {len(train_data) - len(train_clean)} outliers from training data")

# Feature engineering function
def engineer_features(df):
    X = df.copy()
    # Basic statistical features
    X['T_mean'] = X[['T(t-2)', 'T(t-1)', 'T(t)']].mean(axis=1)
    X['T_std'] = X[['T(t-2)', 'T(t-1)', 'T(t)']].std(axis=1)
    X['D_mean'] = X[['D(t-2)', 'D(t-1)', 'D(t)']].mean(axis=1)
    X['D_std'] = X[['D(t-2)', 'D(t-1)', 'D(t)']].std(axis=1)
    # Trend features
    X['D_trend'] = X['D(t)'] - X['D(t-2)']
    X['T_trend'] = X['T(t)'] - X['T(t-2)']
    return X

# Prepare features and target
X_train = engineer_features(train_clean.iloc[:, :6])
y_train = train_clean.iloc[:, 6]  # P(t+1) is the target
X_test = engineer_features(test_data.iloc[:, :6])
y_test = test_data.iloc[:, 6]

# Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
# Price threshold for outliers: 120.25
# Removed 15 outliers from training data

# %% [markdown]
# ## 4. Model Training

# %%
# Initialize XGBoost model
xgb_model = XGBRegressor(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    gamma=0.1,
    random_state=42,
    n_jobs=-1
)

# Train model
xgb_model.fit(X_train_scaled, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=0.1, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=300,
#              n_jobs=-1, num_parallel_tree=None, ...)

# %% [markdown]
# ## 5. Model Evaluation - Metrics

# %%
# Make predictions on training data
y_train_pred = rf_model.predict(X_train_scaled)

# Calculate training metrics
train_rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
train_r2 = r2_score(y_train, y_train_pred)

# Calculate test metrics
test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))
test_r2 = r2_score(y_test, y_test_pred)

# Print all metrics
print("Training Metrics:")
print(f"Train RMSE: {train_rmse:.4f}")
print(f"Train R²: {train_r2:.4f}\n")

print("Test Metrics:")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test R²: {test_r2:.4f}")
# Out:
# Training Metrics:
# Train RMSE: 4.8357
# Train R²: 0.8444
#
# Test Metrics:
# Test RMSE: 19.5308
# Test R²: 0.1773

# %% [markdown]
# ### 6. Feature Importance Analysis

# %%
# Feature Importance visualization
feature_importance = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': xgb_model.feature_importances_
}).sort_values('Importance', ascending=False)

# Plot feature importance
plt.figure(figsize=(12, 8))
sns.barplot(x='Importance', y='Feature', data=feature_importance)
plt.title('Feature Importance (XGBoost)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 7. Actual vs Predicted Prices

# %%
# Plot actual vs predicted prices
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_test_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual vs Predicted Prices')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8. Residual Analysis

# %%
# Calculate residuals
residuals = y_test - y_test_pred

# Plot residuals
plt.figure(figsize=(10, 6))
plt.scatter(y_test_pred, residuals, alpha=0.5)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.tight_layout()
plt.show()
